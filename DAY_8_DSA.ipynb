# %% [markdown]
# <a href="https://colab.research.google.com/github/saranyadondapati75-debug/DSA_CODES/blob/main/DAY_8_DSA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Searching and manipulations in Arrays

# %%
#CHECKING IF AN ELEMENT IS PRESENT IN THE ARRAY OR NOT
#arr=2,5,8,10,15,16
#16
arr=[]
n=int(input("Enter the size of array:"))
print("Enter elements: ")
for i in range(n):
  arr.append(int(input()))
target=int(input("Enter the element you want to find:"))
if target in arr:
  print(target,"Found")
else:
  print(target,"Not Found")
# Out:
# Enter the size of array:3
# Enter elements:
# 1
# 6
# 9
# Enter the element you want to find:4
# 4 Not Found

# %%
##find the index of an element
arr=[]
n=int(input("Enter the size of array:"))
print("Enter elements: ")
for i in range(n):
  arr.append(int(input()))
target=int(input("Enter the element you want to find:"))
if target in arr:
  print(target,"Found at index:", arr.index(target))
else:
  print(target,"Not Found at index value")
# Out:
# Enter the size of array:3
# Enter elements:
# 12
# 45
# 78
# Enter the element you want to find:99
# 99 Not Found at index value

# %%
#using for loop by traversel
arr=[]
n=int(input("Enter the size of array:"))
print("Enter elements: ")
for i in range(n):
  arr.append(int(input()))
target=int(input("Enter the element you want to find:"))
found=False
for i in range(n):
  if arr[i]==target:
    print(target,"Found at index:",i)
    found=True
    break
if found==False:
  print(target,"not Found")
# Out:
# Enter the size of array:3
# Enter elements:
# 12
# 77
# 99
# Enter the element you want to find:99
# 99 Found at index: 2

# %%
#count how many times the element is present in the array
arr=[]
c=0
n=int(input("Enter the size of array: "))
print("Enter elements: ")
for i in range(n):
  arr.append(int(input()))
target=int(input("Enter the element you want to find:"))
for i in range(n):
  if arr[i]==target:
    c+=1
print("Count of",target,"is",c)
# Out:
# Enter the size of array: 4
# Enter elements:
# 12
# 14
# 14
# 14
# Enter the element you want to find:14
# Count of 14 is 3

# %%
#count of positition of an array #to find all the positions of occurance....
arr=[]
n=int(input("Enter the size of array:"))
print("Enter elements: ")
for i in range(n):
  arr.append(int(input()))
target=int(input("Enter the element you want to find:"))
found=False
for i in range(n):
  if arr[i]==target:
    print(target,"Found at index:",i)
    found=True
if found==False:
  print(target,"not Found")
# Out:
# Enter the size of array:4
# Enter elements:
# 12
# 45
# 12
# 12
# Enter the element you want to find:45
# 45 Found at index: 1

# %%
#Index of an element using for loop
r=int(input("Enter rows:"))
c=int(input("Enter cols:"))
arr=[]
print("Enter elements : ")
for i in range(r):
  row=[]
  for j in range(c):
    row.append(int(input()))
  arr.append(row)
target=int(input("Enter the element u want to search: "))
found=False
for i in range(r):
  for j in range(c):
    if arr[i][j]==target:
      print("Target coordinates are ",i,j)
      found= True
if found==False:
  print("Element not found.........")
# Out:
# Enter rows:3
# Enter cols:3
# Enter elements :
# 11
# 22
# 33
# 44
# 55
# 66
# 77
# 88
# 99
# Enter the element u want to search: 77
# Target coordinates are  2 0
