# %% [markdown]
# <a href="https://colab.research.google.com/github/saranyadondapati75-debug/DSA_CODES/blob/main/DAY_5_DSA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##APPROACHES

# %%
##Math approach
num=int(input("Enter a value:"))
if num%2==1:
  print(num,"is odd")
else:
  print(num,"is even")
# Out:
# Enter a value:65
# 65 is odd

# %%
##Naive approach
arr=list(map(int,input("Enter elements:").split()))
largest=arr[0]
for i in range(len(arr)):
  if arr[i]>largest:
    largest=arr[i]
print("Largest: ", largest)
# Out:
# Enter elements:8 1 4 3 2 12  1 0 16
# Largest:  16

# %%
##Brute-Force approach
arr=list(map(int,input("Enter elements").split()))
target=int(input("Enter target:"))
found=False
for i in range(len(arr)):
  for j in range(i+1,len(arr)):
    if arr[i]+arr[j]==target:
      print("Pair Found at:",i,j)
      print("Pair Found are:",arr[i],arr[j])
      found=True
      break
  if found:
    break
if not found:
  print("No pair found")
# Out:
# Enter elements2 4 6 8 10
# Enter target:16
# Pair Found at: 2 4
# Pair Found are: 6 10

# %%
##Brute-Force approach
arr=list(map(int,input("Enter elements").split()))
target=int(input("Enter target:"))
found=False
for i in range(len(arr)):
  for j in range(i+1,len(arr)):
    if arr[i]+arr[j]==target:
      print("Pair Found at:",i,j)
      print("Pair Found are:",arr[i],arr[j])
      found=True
      break
  if found:
    break
if not found:
  print("No pair found")
# Out:
# Enter elements2 4 6 8 10
# Enter target:16
# Pair Found at: 2 4
# Pair Found are: 6 10

# %% [markdown]
# #GREEDY APPROACH

# %%
#GREEDY APPROACH
coins = list(map(int,input("Enter coins").split()))
amount=int(input("Enter target:"))
print("Coins used:")
for coin in coins:
  while amount>=coin:
    print(coin,end=" ")
    amount-=coin
# Out:
# Enter coins20 10 5 2 1
# Enter target:28
# Coins used:
# 20 5 2 1

# %%
def generate(s,n):
  if len(s)==n:
    print(s)
    return
  generate(s+'0',n)
  generate(s+'1',n)
n=int(input("Enter length:"))
generate("",n)
# Out:
# Enter length:3
# 000
# 001
# 010
# 011
# 100
# 101
# 110
# 111
